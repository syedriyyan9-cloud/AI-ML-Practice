# %% [markdown]
# ### Final Phase

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1 = np.array([1,2,3,4,5])
array2 = np.random.rand(3,3)
array3 = np.zeros([4,4])

# %%
np.save("array1.npy", array1)
np.save("array2.npy", array2)
np.save("array3.npy", array3)

# %%
loaded_array1 = np.load("array1.npy")
print(loaded_array1)
# Out:
# [1 2 3 4 5]

# %%
try:
    loaded_array2 = np.load("array2.npy")
    print(loaded_array2)
    plt.figure(figsize=[10, 5])
    plt.plot(loaded_array2)
    plt.title("Random value")
    plt.show()
except FileNotFoundError:
    print("Not found")
# Out:
# [[0.67885084 0.84854705 0.38145261]
#  [0.13562716 0.09691861 0.45139643]
#  [0.23940091 0.06382168 0.97734572]]
